# %%
# %%javascript
# IPython.notebook.clear_all_output();

# %% [markdown]
# # Edge List Loading

# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def plot(G):
    nx.draw_networkx(G, with_labels = True)
    plt.draw()
    plt.show()

# %%
import os

def load(filepath, name = None):
    line_counter = 0
    if name == None: name = os.path.basename(filepath)
    G = nx.Graph(name = name)
    with open(filepath, 'r') as file:
        for line in file:
            v = line.split(',')
            G.add_edge(v[0], v[1][:-1])
            line_counter += 1
            if line_counter % 100000 == 0: print(line_counter, 'lines processed')
    print('====== SUMMARY ======')
    print(nx.info(G))
    return G

# %%
G = load('Dynamic_coexp_Networks/6D_sen_net.csv')
# Out:
# ====== SUMMARY ======
# Name: 6D_sen_net.csv
# Type: Graph
# Number of nodes: 333
# Number of edges: 1363
# Average degree:   8.1862

# %%
def remove_self_loop(G):
    G.remove_edges_from(G.selfloop_edges())
    print('====== SUMMARY ======')
    print(nx.info(G))
    return G

# %%
G = remove_self_loop(G)
# Out:
# ====== SUMMARY ======
# Name: 6D_sen_net.csv
# Type: Graph
# Number of nodes: 333
# Number of edges: 1356
# Average degree:   8.1441

# %% [markdown]
# # k-Core

# %%
import time

def core_sketch(G):
    start_time = time.time()
    sketch = nx.core_number(G)
    elapsed_time = time.time() - start_time
    print('Time Elapsed:', elapsed_time, 'seconds')
    return sketch, max(sketch.values())

def core_components(G, k, sketch):
    start_time = time.time()
    k_core = nx.k_core(G, k=k, core_number=sketch)
    print('====== SUMMARY ======')
    print(nx.info(k_core))
    graphs = [k_core.subgraph(c) for c in nx.connected_components(k_core)]
    elapsed_time = time.time() - start_time
    print('Time Elapsed:', elapsed_time, 'seconds')
    return list(graphs)

def report(components):
    start_time = time.time()
    for g in components:
        print(nx.info(g))
    elapsed_time = time.time() - start_time
    print('Time Elapsed:', elapsed_time, 'seconds')

# %%
sketch, max_core = core_sketch(G)
print('max_core:', max_core)
# Out:
# Time Elapsed: 0.002007007598876953 seconds
# max_core: 12

# %%
graphs = core_components(G, max_core, sketch)
# Out:
# ====== SUMMARY ======
# Name: 6D_sen_net.csv
# Type: Graph
# Number of nodes: 18
# Number of edges: 136
# Average degree:  15.1111
# Time Elapsed: 0.0013952255249023438 seconds

# %%
report(graphs)
# Out:
# Name: 6D_sen_net.csv
# Type: Graph
# Number of nodes: 18
# Number of edges: 136
# Average degree:  15.1111
# Time Elapsed: 0.0002512931823730469 seconds

# %%
plot(graphs[0])
# Out:
# /anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %% [markdown]
# # Frequent Itemset Mining

# %% [markdown]
# We first create transactions of k-cores

# %%
# !!!!!! we now only check till Day 12, not Day 30 !!!!!!

# %%
db = list() # split subgraphs
times = list() # record time step #

for day in range(6,13,2):
    fname = 'Dynamic_coexp_Networks/' + str(day) + 'D_sen_net.csv'
    print('######################## day =', day)
    G = load(fname)
    G = remove_self_loop(G)
    # ------------
    sketch, max_core = core_sketch(G)
    print('max_core:', max_core)
    # ------------
    graphs = core_components(G, max_core, sketch)
    print('#{components}:', len(graphs))
    for graph in graphs:
        itemset = list(graph.nodes)
        db.append(itemset)
        times.append(day)
    print()
# Out:
# ######################## day = 6
# ====== SUMMARY ======
# Name: 6D_sen_net.csv
# Type: Graph
# Number of nodes: 333
# Number of edges: 1363
# Average degree:   8.1862
# ====== SUMMARY ======
# Name: 6D_sen_net.csv
# Type: Graph
# Number of nodes: 333
# Number of edges: 1356
# Average degree:   8.1441
# Time Elapsed: 0.0045130252838134766 seconds
# max_core: 12
# ====== SUMMARY ======
# Name: 6D_sen_net.csv
# Type: Graph
# Number of nodes: 18
# Number of edges: 136
# Average degree:  15.1111
# Time Elapsed: 0.002958059310913086 seconds
# #{components}: 1
#
# ######################## day = 8
# ====== SUMMARY ======
# Name: 8D_sen_net.csv
# Type: Graph
# Number of nodes: 837
# Number of edges: 9127
# Average degree:  21.8088
# ====== SUMMARY ======
# Name: 8D_sen_net.csv
# Type: Graph
# Number of nodes: 837
# Number of edges: 9119
# Average degree:  21.7897
# Time Elapsed: 0.01644587516784668 seconds
# max_core: 36
# ====== SUMMARY ======
# Name: 8D_sen_net.csv
# Type: Graph
# Number of nodes: 77
# Number of edges: 2015
# Average degree:  52.3377
# Time Elapsed: 0.015416145324707031 seconds
# #{components}: 1
#
# ######################## day = 10
# ====== SUMMARY ======
# Name: 10D_sen_net.csv
# Type: Graph
# Number of nodes: 1578
# Number of edges: 43575
# Average degree:  55.2281
# ====== SUMMARY ======
# Name: 10D_sen_net.csv
# Type: Graph
# Number of nodes: 1578
# Number of edges: 43556
# Average degree:  55.2041
# Time Elapsed: 0.1283400058746338 seconds
# max_core: 79
# ====== SUMMARY ======
# Name: 10D_sen_net.csv
# Type: Graph
# Number of nodes: 174
# Number of edges: 10016
# Average degree: 115.1264
# Time Elapsed: 0.07364892959594727 seconds
# #{components}: 1
#
# ######################## day = 12
# 100000 lines processed
# ====== SUMMARY ======
# Name: 12D_sen_net.csv
# Type: Graph
# Number of nodes: 2318
# Number of edges: 126505
# Average degree: 109.1501
# ====== SUMMARY ======
# Name: 12D_sen_net.csv
# Type: Graph
# Number of nodes: 2318
# Number of edges: 126480
# Average degree: 109.1286
# Time Elapsed: 0.8051469326019287 seconds
# max_core: 151
# ====== SUMMARY ======
# Name: 12D_sen_net.csv
# Type: Graph
# Number of nodes: 304
# Number of edges: 32969
# Average degree: 216.9013
# Time Elapsed: 0.24039769172668457 seconds
# #{components}: 1

# %%
n = len(range(6,13,2))
print(n)
# Out:
# 4

# %%
from prefixspan import PrefixSpan

ps = PrefixSpan(db)

# %%
def get_itemsets(ps, tau_freq):
    start_time = time.time()
    result = ps.frequent(tau_freq, closed = True) # !!! consider closed patterns
    elapsed_time = time.time() - start_time
    print('Time Elapsed:', elapsed_time, 'seconds')
    return result

def prune(itemsets, tau_size):
    result = []
    for itemset in itemsets:
        if len(itemset[1]) >= tau_size:
            result.append(itemset)
    return result

# %%
tau_freq = 3 # tune !!! cannot be too small

itemsets = get_itemsets(ps, tau_freq)
print('#{patterns}:', len(itemsets))
# Out:
# Time Elapsed: 0.07085704803466797 seconds
# #{patterns}: 15

# %%
tau_size = 1 # tune !!! this is a cheap pruning, do not rerun get_itemsets !!!

pruned = prune(itemsets, tau_size)
print('#{patterns}:', len(pruned))
# Out:
# #{patterns}: 15

# %%
display(pruned)
# Out:
# [(4, ['AT4G37520', 'AT5G41410', 'AT1G79270']),
#  (4, ['AT4G37520', 'AT5G41410', 'AT5G60360', 'AT3G25585', 'AT5G61820']),
#  (4, ['AT4G37520', 'AT5G41410', 'AT5G60360', 'AT2G37760', 'AT4G27745']),
#  (4, ['AT4G37520', 'AT5G41410', 'AT5G60360', 'AT2G37760', 'AT1G09240']),
#  (4, ['AT4G37520', 'AT4G18210', 'AT5G61820']),
#  (4, ['AT4G37520', 'AT4G18210', 'AT2G37760', 'AT4G27745']),
#  (4, ['AT4G37520', 'AT4G18210', 'AT2G37760', 'AT1G09240']),
#  (3, ['AT3G15580', 'AT4G18210', 'AT5G61820']),
#  (3, ['AT3G15580', 'AT4G18210', 'AT2G37760', 'AT4G27745']),
#  (3, ['AT3G15580', 'AT4G18210', 'AT2G37760', 'AT1G09240']),
#  (3, ['AT4G14020', 'AT4G27745']),
#  (3, ['AT4G14020', 'AT1G09240']),
#  (3,
#   ['AT2G39270',
#    'AT4G36195',
#    'AT4G16190',
#    'AT5G01520',
#    'AT3G16190',
#    'AT5G54080',
#    'AT3G01470',
#    'AT3G28050',
#    'AT4G37520',
#    'AT4G18210',
#    'AT5G41410',
#    'AT1G35190',
#    'AT5G60360',
#    'AT2G37760',
#    'AT1G09240',
#    'AT2G22660',
#    'AT3G08690',
#    'AT5G58350',
#    'AT1G64950',
#    'AT4G15530',
#    'AT5G25540',
#    'AT1G64360',
#    'AT1G29970',
#    'AT1G32230',
#    'AT4G24990',
#    'AT4G27745',
#    'AT5G61640',
#    'AT4G22260',
#    'AT3G25585',
#    'AT5G61820',
#    'AT2G42890',
#    'AT4G16790',
#    'AT1G33970',
#    'AT3G51730',
#    'AT3G03470',
#    'AT5G51070',
#    'AT5G63030',
#    'AT5G64430']),
#  (3,
#   ['AT2G39270',
#    'AT4G36195',
#    'AT4G16190',
#    'AT5G01520',
#    'AT3G16190',
#    'AT5G54080',
#    'AT3G01470',
#    'AT3G28050',
#    'AT4G37520',
#    'AT4G18210',
#    'AT5G41410',
#    'AT1G35190',
#    'AT5G60360',
#    'AT2G37760',
#    'AT1G09240',
#    'AT2G22660',
#    'AT3G08690',
#    'AT5G58350',
#    'AT1G64950',
#    'AT4G15530',
#    'AT5G25540',
#    'AT1G64360',
#    'AT1G29970',
#    'AT1G32230',
#    'AT4G24990',
#    'AT4G27745',
#    'AT5G61640',
#    'AT4G22260',
#    'AT3G25585',
#    'AT5G61820',
#    'AT2G42890',
#    'AT4G16790',
#    'AT1G33970',
#    'AT3G51730',
#    'AT3G03470',
#    'AT1G79270',
#    'AT5G63030',
#    'AT5G64430']),
#  (3,
#   ['AT2G39270',
#    'AT4G36195',
#    'AT4G16190',
#    'AT5G01520',
#    'AT3G16190',
#    'AT5G54080',
#    'AT3G01470',
#    'AT3G28050',
#    'AT4G37520',
#    'AT4G18210',
#    'AT5G41410',
#    'AT1G35190',
#    'AT5G60360',
#    'AT2G37760',
#    'AT1G09240',
#    'AT2G22660',
#    'AT3G08690',
#    'AT5G58350',
#    'AT1G64950',
#    'AT1G17080'])]

# %% [markdown]
# # Attaching Time Labels

# %%
db_sets = []
for row in db:
    db_sets.append(set(row))

# %%
def get_time(itemlist):
    result = list()
    for i in range(len(db_sets)):
        time_step = times[i]
        superset = db_sets[i]
        if superset.issuperset(itemlist):
            result.append(time_step)
    return result

# %%
get_time(['AT4G37520', 'AT5G41410', 'AT5G60360', 'AT2G37760', 'AT1G09240'])
# Out:
# [6, 8, 10, 12]

# %%
patt_file = 'output.txt'

# %%
fout = open(patt_file, 'w')
patt_counter = 0
n_patt = len(pruned)

for freq, pattern in pruned:
    time_snapshots = get_time(pattern)
    assert len(time_snapshots) == freq, '[ERROR] pattern frequency mismatch'
    patt_counter += 1
    if patt_counter % 10000 == 0: print(patt_counter, 'patterns processed among', n_patt)
    # ------
    fout.write('#\n')
    for item in time_snapshots:
        fout.write(str(item) + ' ')
    fout.write('\n')
    for item in pattern:
        fout.write(str(item) + ' ')
    fout.write('\n')
fout.close()

# %%
class temp_patt:
    # time_seq
    # node_set
    
    def __lt__(self, other): # sort by length, large goes first
        return len(self.node_set) > len(other.node_set)
    
    def plot(self, G):
        plt.rcParams["figure.figsize"] = (20,10)
        subG = G.subgraph(self.node_set)
        nx.draw_circular(subG, with_labels = True, font_color = 'r', font_size = 20, node_color = 'y')
        plt.draw()
        plt.show()

patts = list()

fin = open(patt_file, 'r')
temp = None
state = 0
for line in fin:
    if line[0] == '#':
        temp = temp_patt()
        state = 1
    elif state == 1:
        items = line[:-2].split(' ') # remove space + \n
        temp.time_seq = [int(x) for x in items]
        state = 2
    else:
        temp.node_set = line[:-2].split(' ') # remove space + \n
        patts.append(temp)
fin.close()

# %% [markdown]
# # Printing Patterns Ordered by Pattern Length

# %%
patts = sorted(patts)

# %%
for patt in patts:
    print(patt.time_seq)
    print(patt.node_set)
    print()
# Out:
# [8, 10, 12]
# ['AT2G39270', 'AT4G36195', 'AT4G16190', 'AT5G01520', 'AT3G16190', 'AT5G54080', 'AT3G01470', 'AT3G28050', 'AT4G37520', 'AT4G18210', 'AT5G41410', 'AT1G35190', 'AT5G60360', 'AT2G37760', 'AT1G09240', 'AT2G22660', 'AT3G08690', 'AT5G58350', 'AT1G64950', 'AT4G15530', 'AT5G25540', 'AT1G64360', 'AT1G29970', 'AT1G32230', 'AT4G24990', 'AT4G27745', 'AT5G61640', 'AT4G22260', 'AT3G25585', 'AT5G61820', 'AT2G42890', 'AT4G16790', 'AT1G33970', 'AT3G51730', 'AT3G03470', 'AT5G51070', 'AT5G63030', 'AT5G64430']
#
# [8, 10, 12]
# ['AT2G39270', 'AT4G36195', 'AT4G16190', 'AT5G01520', 'AT3G16190', 'AT5G54080', 'AT3G01470', 'AT3G28050', 'AT4G37520', 'AT4G18210', 'AT5G41410', 'AT1G35190', 'AT5G60360', 'AT2G37760', 'AT1G09240', 'AT2G22660', 'AT3G08690', 'AT5G58350', 'AT1G64950', 'AT4G15530', 'AT5G25540', 'AT1G64360', 'AT1G29970', 'AT1G32230', 'AT4G24990', 'AT4G27745', 'AT5G61640', 'AT4G22260', 'AT3G25585', 'AT5G61820', 'AT2G42890', 'AT4G16790', 'AT1G33970', 'AT3G51730', 'AT3G03470', 'AT1G79270', 'AT5G63030', 'AT5G64430']
#
# [8, 10, 12]
# ['AT2G39270', 'AT4G36195', 'AT4G16190', 'AT5G01520', 'AT3G16190', 'AT5G54080', 'AT3G01470', 'AT3G28050', 'AT4G37520', 'AT4G18210', 'AT5G41410', 'AT1G35190', 'AT5G60360', 'AT2G37760', 'AT1G09240', 'AT2G22660', 'AT3G08690', 'AT5G58350', 'AT1G64950', 'AT1G17080']
#
# [6, 8, 10, 12]
# ['AT4G37520', 'AT5G41410', 'AT5G60360', 'AT3G25585', 'AT5G61820']
#
# [6, 8, 10, 12]
# ['AT4G37520', 'AT5G41410', 'AT5G60360', 'AT2G37760', 'AT4G27745']
#
# [6, 8, 10, 12]
# ['AT4G37520', 'AT5G41410', 'AT5G60360', 'AT2G37760', 'AT1G09240']
#
# [6, 8, 10, 12]
# ['AT4G37520', 'AT4G18210', 'AT2G37760', 'AT4G27745']
#
# [6, 8, 10, 12]
# ['AT4G37520', 'AT4G18210', 'AT2G37760', 'AT1G09240']
#
# [6, 8, 10]
# ['AT3G15580', 'AT4G18210', 'AT2G37760', 'AT4G27745']
#
# [6, 8, 10]
# ['AT3G15580', 'AT4G18210', 'AT2G37760', 'AT1G09240']
#
# [6, 8, 10, 12]
# ['AT4G37520', 'AT5G41410', 'AT1G79270']
#
# [6, 8, 10, 12]
# ['AT4G37520', 'AT4G18210', 'AT5G61820']
#
# [6, 8, 10]
# ['AT3G15580', 'AT4G18210', 'AT5G61820']
#
# [6, 8, 10]
# ['AT4G14020', 'AT4G27745']
#
# [6, 8, 10]
# ['AT4G14020', 'AT1G09240']

# %% [markdown]
# # Plot Patterns

# %%
i = 0

print(patts[i].time_seq)
patts[i].plot(G)
# Out:
# [8, 10, 12]

# %%
i = 10

print(patts[i].time_seq)
patts[i].plot(G)
# Out:
# [6, 8, 10, 12]

# %% [markdown]
# # Merge Result Graphs

# %%
G_cur = load('Dynamic_coexp_Networks/10D_sen_net.csv') # time = 10
# Out:
# ====== SUMMARY ======
# Name: 10D_sen_net.csv
# Type: Graph
# Number of nodes: 1578
# Number of edges: 43575
# Average degree:  55.2281

# %%
G_merge = nx.Graph(name = 'MERGE')

for patt in pruned:
  node_set = patt[1]
  G_sub = G_cur.subgraph(node_set)
  G_merge = nx.compose(G_merge, G_sub)

# %%
print(nx.info(G_merge))
# Out:
# Name: 10D_sen_net.csv
# Type: Graph
# Number of nodes: 42
# Number of edges: 690
# Average degree:  32.8571

# %%
def plot(G):
  plt.rcParams["figure.figsize"] = (20,20)
  nx.draw_spring(G, with_labels = True, font_color = 'r', font_size = 20, node_color = 'y')
  plt.draw()
  plt.show()

# %%
plot(G_merge)

# %%
# The END
